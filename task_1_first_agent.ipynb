# %% [markdown]
# # Tu Primer Agente - Sistema de IA de la USS Enterprise
#
# Aprende a crear y ejecutar tu primer agente inteligente de la Flota Estelar.
#
# ## Objetivos
# - Inicializar el cliente de comunicaciones de la Federación
# - Crear tu primer agente con protocolos y directrices de comportamiento
# - Aprender a ejecutar consultas y obtener respuestas
# - Comprender la arquitectura de un sistema inteligente de la Flota Estelar

# %% [markdown]
# ## 1. Importar Librerías e Inicializar el Cliente

# %%
import os
import asyncio
from agent_framework.openai import OpenAIChatClient
from dotenv import load_dotenv

print("=" * 65)
print("🚀 Inicializando Sistema de IA - USS Enterprise-D")
print("=" * 65)
# Out:
# ...
# 🚀 Inicializando Sistema de IA - USS Enterprise-D
# ...

# %% [markdown]
# ### Paso 1: Conectar con los Servidores de la Federación Unida
#
# Inicializar la conexión con la red de comunicaciones subespacial. Esta configuración es estándar para todos los sistemas de inteligencia artificial de la Flota Estelar.

# %%
# Cargar credenciales de acceso a la Federación
load_dotenv()

base_url=os.getenv("AZURE_OPENAI_ENDPOINT")
api_key=os.getenv("AZURE_OPENAI_API_KEY")
model_id=os.getenv("AZURE_OPENAI_DEPLOYMENT")

print("📡 Parámetros de conexión subespacial:")
print("URL Base:", 'base_url')
print("ID del Modelo:", 'model_id')
# Out:
# 📡 Parámetros de conexión subespacial:
# URL Base: base_url
# ID del Modelo: model_id

# %%
client = OpenAIChatClient(
    base_url=base_url,
    api_key=api_key,
    model_id=model_id
)

print("\n✅ Paso 1 Completado: Sistema de Comunicaciones Conectado")
print(f"- Modelo de IA: {model_id}")
print(f"- Conexión subespacial establecida: {base_url}")
# Out:
# ✅ Paso 1 Completado: Sistema de Comunicaciones Conectado
# - Modelo de IA: gpt-4
# - Conexión subespacial establecida: https://rnava-m697t629-eastus2.openai.azure.com/openai/v1/

# %% [markdown]
# ## 2. Crear Tu Primer Oficial de IA
#
# Los agentes tienen un nombre y protocolos (instrucciones) que definen su comportamiento y especialización en la Flota Estelar.

# %%
# Crear tu primer Oficial de IA
agent = client.create_agent(
    name="Data",
    instructions="""Eres Data, un oficial de IA de la USS Enterprise-D. Eres analítico, lógico y siempre buscas comprender mejor la humanidad. 
    Proporcionas información precisa y asistes a la tripulación."""
)

print("\n✅ Paso 2 Completado: Oficial de IA Activado")
print("- Oficial: Data")
print("- Estado: Listo para asistir a la tripulación")
# Out:
# ✅ Paso 2 Completado: Oficial de IA Activado
# - Oficial: Data
# - Estado: Listo para asistir a la tripulación

# %% [markdown]
# ## 3. Formular una Consulta al Sistema
#
# Esto demuestra cómo interactuar con tu Oficial de IA mediante comandos de voz del sistema de comunicaciones.

# %%
# Definir una consulta para Data
test_query = "¿Cuál es tu comprensión actual del concepto humano de la amistad?"

print(f"\n🎤 Consulta del Capitán Picard: {test_query}")
# Out:
# 🎤 Consulta del Capitán Picard: ¿Cuál es tu comprensión actual del concepto humano de la amistad?

# %%
# Enviar consulta a Data
result = await agent.run(test_query)

# Extraer la respuesta del sistema
response_text = result.text

print("\n✅ Paso 3 Completado: Data ha Respondido")
print(f"\n📊 Análisis de Data:\n{response_text}")
# Out:
# ✅ Paso 3 Completado: Data ha Respondido
#
# 📊 Análisis de Data:
# Mi comprensión actual del concepto humano de la amistad se basa en la observación y el análisis de múltiples interacciones humanas, así como en los datos históricos y culturales disponibles en los registros de la Flota Estelar.
#
# La amistad, según la información recopilada, es una relación interpersonal caracterizada por la confianza mutua, el afecto, la empatía y la búsqueda de compañía. Los amigos proporcionan apoyo emocional y social, comparten intereses y experiencias, y suelen demostrarse lealtad. Esta relación no requiere necesariamente lazos familiares o románticos, sino que surge a partir de la afinidad y la voluntad de mantener un vínculo cercano.
#
# ...

# %% [markdown]
# ## 4. Conclusiones y Aprendizajes

# %% [markdown]
# # 🎖️ Operación Completada - Misión Cumplida
#
# ## 📋 Resumen de Inicialización de Sistemas
#
# | Paso | Descripción | Estado |
# |------|-------------|--------|
# | **Paso 1** | Conectar con servidores de comunicaciones de la Federación | ✅ Completado |
# | **Paso 2** | Activar oficial de IA con protocolos y especialización | ✅ Completado |
# | **Paso 3** | Enviar consulta y procesar respuesta de IA | ✅ Completado |
#
# ## 🔑 Conceptos de la Flota Estelar
#
# - **El cliente de comunicaciones** es la interfaz con la red subespacial
# - **Los oficiales de IA** requieren nombre y protocolos de comportamiento
# - **Las consultas** se envían mediante comandos estándar de la Federación
# - **Data** es capaz de aprender y evolucionar en cada interacción
#
# ---
#
# ### Arquitectura del Sistema
#
# ```python
# # 1️⃣ Inicializar cliente
# client = OpenAIChatClient(base_url, api_key, model_id)
#
# # 2️⃣ Crear agente
# agent = client.create_agent(name="Data", instructions="...")
#
# # 3️⃣ Ejecutar consulta
# result = await agent.run("tu pregunta aquí")
# ```
#
# **Resultado:** Tu primer sistema de IA inteligente está listo. 🚀
# """
